# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x1e0e3ef4df0>,
#  <matplotlib.lines.Line2D at 0x1e0e3ef4d30>]

# %%
plt.scatter(df["YearsExperience"],df["Salary"])

# %% [markdown]
# ## TrainTestSplit

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df["YearsExperience"],df["Salary"],test_size = 0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
X_train = X_train.values.reshape(-1,1)

# %%
X_test = X_test.values.reshape(-1,1)

# %%
X_train.shape
# Out:
# (24, 1)

# %%
X_test.shape
# Out:
# (6, 1)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
linear_accuracy = round(lr.score(X_test, y_test) , 5)

# %%
linear_accuracy
# Out:
# 0.90245

# %%
lr.predict([[2]])
# Out:
# array([44169.21365784])

# %%
import pickle

# %%
pickle.dump(lr,open('model.pkl','wb'))

# %%
model = pickle.load(open('model.pkl','rb'))
print(model.predict([[6]]))
# Out:
# [81864.47494996]

# %%
print(model.predict([[3]]))
# Out:
# [53593.02898087]

# %%
 import flask
 flask.__version__
# Out:
# '1.1.2'

# %%
pipreqs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-5ffbe6631a3f> in <module>
# ----> 1 pipreqs
#
# NameError: name 'pipreqs' is not defined

# %%
pipreqs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-5ffbe6631a3f> in <module>
# ----> 1 pipreqs
#
# NameError: name 'pipreqs' is not defined

# %%
pip install pipreqs
# Out:
# Requirement already satisfied: pipreqs in c:\programdata\anaconda3\lib\site-packages (0.4.10)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: docopt in c:\programdata\anaconda3\lib\site-packages (from pipreqs) (0.6.2)
# Requirement already satisfied: yarg in c:\programdata\anaconda3\lib\site-packages (from pipreqs) (0.1.9)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from yarg->pipreqs) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->yarg->pipreqs) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->yarg->pipreqs) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->yarg->pipreqs) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->yarg->pipreqs) (2020.6.20)

# %%
pipreqs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-5ffbe6631a3f> in <module>
# ----> 1 pipreqs
#
# NameError: name 'pipreqs' is not defined
